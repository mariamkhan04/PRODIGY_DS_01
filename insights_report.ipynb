# %% [markdown]
# ## **Detailed Insights on Variable Distributions Visualized in [main.ipynb](main.ipynb)**

# %% [markdown]
# ### **1. Insights from Categorical Variables Distributions**
#
# #### **Insights from Gender Distribution**
# - The dataset includes data for **517 male users (51.7%)** and **483 female users (48.3%)**.
# - The distribution is nearly balanced, with slightly more male users than female users.
# - On average, there are **500 users per gender**, with a standard deviation of **24.04**, showing minimal variation between the two groups.
# - This balanced distribution ensures fair representation and reduces the risk of bias in gender-based analyses or comparisons.
#
# ![image.png](attachment:image.png)
#
# #### **Insights from Location Distribution**
# - The dataset contains data from five locations, showing the **number of users** in each.
# - **New York** has the highest number of users (243), while **Houston** has the lowest (181).
# - The average number of users across locations is **200**, with a standard deviation of **25**, indicating moderate variation.
# - The interquartile range (IQR) is 14 (199 - 185), showing most locations have similar user counts, except for New York, which stands out.
# - The distribution is fairly balanced, but **New York is overrepresented**, contributing to 24.3% of the total users in the dataset.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### **2. Insights from Continuous Variables Distributions**
#
# #### **Insights from User_ID Distribution**
# - **User_ID** values are **uniformly distributed** (equal frequency in each bin).
# - **Range**: 1 to 1000, with mean and median both at **500.5**.
# - **No outliers or clustering**: data is **evenly spread** and **symmetric**.
# - **Standard deviation**: **~288.82**, confirming **consistent distribution**.
#
# ![image.png](attachment:image.png)
#
# #### **Insights from Age Distribution**
# - The dataset includes **1,000 mobile users aged between 18 and 59 years**.
# - The mean age of users is approximately **38.7 years**, with a standard deviation of **12.19 years**. This means the ages of mobile users tend to cluster around the average, showing **less variability** in the data.
# - The **age group 20–29** shows the **highest frequency**, indicating a larger proportion of younger users.
# - Users are fairly evenly distributed across the remaining age groups (30–59 years).
# - The median age (40 years) and the interquartile range (28–50 years) indicate a **balanced user distribution around the central age range.**
#
# ![image-2.png](attachment:image-2.png)
#
# #### **Insights from Total App Usage Hours**
# - The dataset includes 1,000 users with **app usage ranging from 1 to 12 hours daily**.
# - The mean daily usage is approximately **6.4 hours**, indicating **moderate** engagement.
# - The standard deviation of **3.13** hours shows a **moderate spread in usage patterns** around the mean.
# - The median daily usage is **6.45 hours**, similar to the mean, suggesting a **symmetric distribution**.
# - The interquartile range **(3.59 - 9.12 hours)** indicates that **50% of users spend 3.59 to 9.12 hours daily on apps**.
# - Most users are evenly distributed across usage hours, with slightly higher frequency around **8 hours**.
#
# ![image-3.png](attachment:image-3.png)
#
# #### **Insights from Daily Screen Time Hours**
# - The dataset includes 1,000 users with **daily screen time ranging from 1.01 to 14 hours**.
# - The mean daily screen time is approximately **7.7** hours, indicating **high average screen usage.**
# - The standard deviation of **3.71** hours suggests **significant variability in screen time among users**.
# - The median daily screen time is **7.88** hours, close to the mean, implying a fairly **symmetric distribution**.
# - The interquartile range **(4.53–10.91 hours)** shows that **50% of users spend between 4.53 to 10.91 hours on screens daily**.
# - Users with very low **(<4 hours)** or very high **(>11 hours)** screen time represent the **extremes** of the data distribution.
#
# ![image-4.png](attachment:image-4.png)
#
# #### **Insights from Number of Apps Used**
# - The dataset contains 1,000 users, using between **3 and 29 apps**.
# - The mean number of apps used is approximately **16.65**, indicating **moderate app usage**.
# - The standard deviation of **7.62** suggests **considerable variability** in the number of apps used among users.
# - The median is **17** apps, close to the mean, implying a balanced and **symmetric** distribution.
# - The interquartile range **(10–23 apps)** shows that 50% of users use between 10 and 23 apps.
# - The distribution highlights **light users (<10 apps)** and **heavy users (>23 apps)** as notable extremes.
#
# ![image-5.png](attachment:image-5.png)
#
# #### **Insights from Social Media Usage Hours**
# - The dataset contains 1000 users , spending **0 to 4.99 hours** daily on social media.
# - On average **2.45 hours** are spend on social media showing **moderate** usage/engagement.
# - The standard deviation of **1.43 hours** shows **limited variability** in social media usage.
# - The IQR **(1.2-3.67)** hours , indicates taht 50% of the users spend about 1.2 to 3.67 hours on social media daily.
# - The median **2.44** hours , close to mean indicates that it is a **balanced** and **symmetric** distribution.
# - Some users show **no engagement** (0 hours), while the maximum usage reaches nearly 5 hours, highlighting the extremes.
#
# ![image-6.png](attachment:image-6.png)
#
# #### **Insights from Productivity App Usage Hours**
# - The dataset contains 1000 users, spending **0 to 5 hours** daily on Productivity Apps.
# - The average usage hours per user is **2.5 hours**, with a standard deviation of **1.44 hours** indicating **moderate engagement** and **limited variability**.
# - The median **2.43 hours** is nearly equal to mean indicating **balanced** distribution.
# - The interquartile range (1.28–3.71 hours) shows that 50% of users spend between **1.28 to 3.71 hours** on productivity apps daily.
# - Some users report **no usage** (0 hours), while the maximum usage reaches **5 hours**, highlighting the extremes.
#
# ![image-7.png](attachment:image-7.png)
#
# #### **Insights from Gaming App Usage Hours**
# - The dataset contains 1,000 users with gaming app usage ranging from **0.01 to 5 hours daily**.
# - The mean usage is approximately **2.48 hours**, indicating moderate engagement with gaming apps.
# - The standard deviation of **1.45 hours** suggests limited variability, with most user's usage clustered around the mean.
# - The median usage is **2.46 hours**, very close to the mean, indicating a symmetrical distribution.
# - The interquartile range (1.22–3.78 hours) shows that **50% of users spend between 1.22 to 3.78 hours** on gaming apps daily.
# - While some users spend minimal time (as low as **0.01 hours**), the maximum usage recorded is **5 hours**.
#
# ![image-8.png](attachment:image-8.png)
